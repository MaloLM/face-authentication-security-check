# %%
from ultralytics import YOLO

model = YOLO("../models/yolov8s-oiv7.pt", task='detect')

# %%
model.export(format="engine", dynamic=True, half=True) # int8=True
# Out:
# WARNING ⚠️ TensorRT requires GPU export, automatically assigning device=0
# Ultralytics YOLOv8.2.95 🚀 Python-3.12.5 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# YOLOv8s summary (fused): 168 layers, 11,358,171 parameters, 0 gradients, 29.7 GFLOPs
#
# PyTorch: starting from '../models/yolov8s-oiv7.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 605, 8400) (21.9 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 52.9 MB/s eta 0:00:00 0:00:01
# ...
#
# requirements: AutoUpdate success ✅ 2.7s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.16.2 opset 19...
# ONNX: export success ✅ 3.9s, saved as '../models/yolov8s-oiv7.onnx' (43.4 MB)
# requirements: Ultralytics requirement ['tensorrt>7.0.0,<=10.1.0'] not found, attempting AutoUpdate...
# ...
